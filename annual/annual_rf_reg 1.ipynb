# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score

from datetime import datetime
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.collections import LineCollection

import statsmodels as sms
import statsmodels.formula.api as smf
from scipy import stats

# %%
data1 = pd.read_pickle('real_fore_prc1.pkl')
data1 = data1.reset_index()

# %%
data1['year'] = data1.statpers_1.dt.year

# %%
tr1 = data1.loc[(1986 <= data1['year']) & (data1['year'] <= 2009)].dropna()
ts1 = data1.loc[(2010 <= data1['year']) & (data1['year'] <= 2020)].dropna()

# %%
data1.head(15)
# Out:
#    statpers_1  permno     prc      jdate ticker    anndats  past_eps  \
# 0  1991-09-19   10001   9.750 1990-09-30   GFGC 1991-09-18      1.01
# 1  1991-09-19   10001   9.625 1990-10-31   GFGC 1991-09-18      1.01
# 2  1991-09-19   10001   9.625 1990-11-30   GFGC 1991-09-18      1.01
# 3  1991-09-19   10001   9.500 1990-12-31   GFGC 1991-09-18      1.01
# 4  1991-09-19   10001   9.625 1991-01-31   GFGC 1991-09-18      1.01
# 5  1991-09-19   10001   9.750 1991-02-28   GFGC 1991-09-18      1.01
# 6  1991-09-19   10001   9.500 1991-03-31   GFGC 1991-09-18      1.01
# 7  1991-09-19   10001   9.875 1991-04-30   GFGC 1991-09-18      1.01
# 8  1991-09-19   10001   9.875 1991-05-31   GFGC 1991-09-18      1.01
# 9  1991-09-19   10001  10.500 1991-06-30   GFGC 1991-09-18      1.01
# 10 1991-09-19   10001  10.125 1991-07-31   GFGC 1991-09-18      1.01
# 11 1991-09-19   10001  11.500 1991-08-31   GFGC 1991-09-18      1.01
# 12 1992-09-17   10001  11.500 1991-09-30   GFGC 1992-08-26      0.77
# 13 1992-09-17   10001  13.000 1991-10-31   GFGC 1992-08-26      0.77
# 14 1992-09-17   10001  14.750 1991-11-30   GFGC 1992-08-26      0.77
#
#     pred_date  pred_eps  mean_fpi1  year
# 0  1992-08-31      0.77       1.13  1991
# 1  1992-08-31      0.77       1.13  1991
# 2  1992-08-31      0.77       1.13  1991
# 3  1992-08-31      0.77       1.13  1991
# 4  1992-08-31      0.77       1.13  1991
# 5  1992-08-31      0.77       1.13  1991
# 6  1992-08-31      0.77       1.13  1991
# 7  1992-08-31      0.77       1.13  1991
# 8  1992-08-31      0.77       1.13  1991
# 9  1992-08-31      0.77       1.13  1991
# 10 1992-08-31      0.77       1.13  1991
# 11 1992-08-31      0.77       1.13  1991
# 12 1993-09-30      1.18       1.13  1992
# 13 1993-09-30      1.18       1.13  1992
# 14 1993-09-30      1.18       1.13  1992

# %%
tr1 = tr1.sort_values(by = ['permno', 'statpers_1', 'jdate']).drop_duplicates(subset = ['permno','statpers_1'], keep = 'last')
ts1 = ts1.sort_values(by = ['permno', 'statpers_1', 'jdate']).drop_duplicates(subset = ['permno','statpers_1'], keep = 'last')

# %%
X_tr1 = tr1[['prc', 'past_eps', 'mean_fpi1']]
y_tr1 = tr1['pred_eps']
X_ts1 = ts1[['prc', 'past_eps', 'mean_fpi1']]
y_ts1 = ts1['pred_eps']

# %%
X_tr1.shape
# Out:
# (74787, 3)

# %%
X_ts1.shape
# Out:
# (24718, 3)

# %%
tr1.head(20)
# Out:
#     statpers_1  permno        prc      jdate ticker    anndats  past_eps  \
# 11  1991-09-19   10001  11.500000 1991-08-31   GFGC 1991-09-18     1.010
# 23  1992-09-17   10001  13.000000 1992-08-31   GFGC 1992-08-26     0.770
# 35  1993-09-16   10001  15.875000 1993-08-31   GFGC 1993-09-01     1.180
# 47  1995-01-19   10001   8.000000 1994-12-31   GFGC 1995-01-18     0.515
# 55  1995-09-14   10001   8.000000 1995-08-31   GFGC 1995-09-14     0.680
# 67  1997-06-19   10001   8.625000 1997-05-31   GFGC 1997-06-03     0.650
# 69  1997-08-14   10001   8.625000 1997-07-31   GFGC 1997-07-21     0.950
# 74  1998-01-15   10001   9.000000 1997-12-31   GFGC 1998-01-07     0.550
# 85  1998-12-17   10001   9.437500 1998-11-30   GFGC 1998-11-30     0.640
# 94  1999-09-16   10001   8.750000 1999-08-31   GFGC 1999-09-10     0.660
# 106 2000-12-14   10001   9.562500 2000-11-30   GFGC 2000-11-28     0.530
# 177 2003-02-20   10002  11.810000 2003-01-31   BTFG 2003-01-31     0.840
# 189 2004-02-19   10002  16.110001 2004-01-31   BTFG 2004-02-12     0.710
# 201 2005-02-17   10002  21.350000 2005-01-31   BTFG 2005-01-24     0.960
# 213 2006-02-16   10002  20.700001 2006-01-31   BTFG 2006-01-20     1.190
# 225 2007-02-15   10002  21.480000 2007-01-31   BTFG 2007-01-31     1.190
# 237 2008-02-14   10002  12.350000 2008-01-31   BTFG 2008-02-08     0.490
# 249 2009-02-19   10002   8.870000 2009-01-31   BTFG 2009-02-16     0.060
# 260 1986-12-18   10008  13.750000 1986-11-30   GACO 1986-12-18     1.050
# 272 1990-02-15   10009   6.500000 1990-01-31   CAYB 1990-02-08     0.740
#
#      pred_date  pred_eps  mean_fpi1  year
# 11  1992-08-31     0.770       1.13  1991
# 23  1993-09-30     1.180       1.13  1992
# 35  1995-01-31     0.515       1.33  1993
# 47  1995-09-30     0.680       0.61  1995
# 55  1997-07-31     0.950       0.70  1995
# 67  1998-11-30     0.640       0.63  1997
# 69  1998-01-31     0.550       0.62  1997
# 74  1998-11-30     0.640       0.61  1998
# 85  1999-09-30     0.660       0.63  1998
# 94  2000-11-30     0.530       0.65  1999
# 106 2001-09-30     1.100       0.71  2000
# 177 2004-02-29     0.710       0.88  2003
# 189 2005-01-31     0.960       0.82  2004
# 201 2006-01-31     1.190       1.19  2005
# 213 2007-01-31     1.190       1.34  2006
# 225 2008-02-29     0.490       1.16  2007
# 237 2009-02-28     0.060       1.10  2008
# 249 2010-01-31    -1.350      -0.34  2009
# 260 1987-12-31     0.890       1.33  1986
# 272 1991-01-31     1.380       1.20  1990

# %%
from datetime import datetime
for i in [3, 5, 7]:
    rf = RandomForestRegressor(random_state=0, n_estimators=100, max_depth=i, n_jobs=-1)
    rf.fit(X_tr1, y_tr1)
    yhat_tr1 = rf.predict(X_tr1)
    yhat_ts1 = rf.predict(X_ts1)
    inr2 = r2_score(y_tr1, yhat_tr1)
    outr2 = r2_score(y_ts1, yhat_ts1)
    print(datetime.now(), i, inr2, outr2)
# Out:
# 2020-11-16 11:19:50.593707 3 0.9914861038646156 0.7958120401357742
# 2020-11-16 11:19:51.481166 5 0.9940971975091619 0.798847180498772
# 2020-11-16 11:19:52.459882 7 0.9938724058348977 0.7953316007919768

# %%
for i in [3, 5, 7]:
    rf = RandomForestRegressor(random_state=0, n_estimators=50, max_depth=i, n_jobs=-1)
    rf.fit(X_tr1, y_tr1)
    yhat_tr1 = rf.predict(X_tr1)
    yhat_ts1 = rf.predict(X_ts1)
    inr2 = r2_score(y_tr1, yhat_tr1)
    outr2 = r2_score(y_ts1, yhat_ts1)
    print(datetime.now(), i, inr2, outr2)
# Out:
# 2020-11-16 11:19:57.246436 3 0.9909384123338816 0.7916824897558781
# 2020-11-16 11:19:57.797500 5 0.9925920744494531 0.7937659258256525
# 2020-11-16 11:19:58.457931 7 0.9926390756433345 0.7903381996527996

# %%
data2 = pd.read_pickle('real_fore_prc2.pkl')
data2 = data2.reset_index()

# %%
data2['year'] = data2.statpers_2.dt.year

# %%
tr2 = data2.loc[(1986 <= data2['year']) & (data2['year'] <= 2009)].dropna().sort_values(by = ['permno', 'statpers_2', 'jdate']).drop_duplicates(subset = ['permno','statpers_2'], keep = 'last')
ts2 = data2.loc[(2010 <= data2['year']) & (data2['year'] <= 2020)].dropna().sort_values(by = ['permno', 'statpers_2', 'jdate']).drop_duplicates(subset = ['permno', 'statpers_2'], keep = 'last')

# %%
tr2.head(15)
# Out:
#     statpers_2  permno        prc      jdate ticker    anndats  past_eps  \
# 23  1991-07-18   10001  10.500000 1991-06-30   GFGC 1990-08-29     1.090
# 36  1992-08-20   10001  12.500000 1992-07-31   GFGC 1991-09-18     1.010
# 46  1993-06-17   10001  15.125000 1993-05-31   GFGC 1992-08-26     0.770
# 57  1994-05-19   10001  14.750000 1994-04-30   GFGC 1993-09-01     1.180
# 72  1995-08-17   10001   8.250000 1995-07-31   GFGC 1995-01-18     0.515
# 83  1996-07-18   10001   8.000000 1996-06-30   GFGC 1995-09-14     0.680
# 96  1997-08-14   10001   8.625000 1997-07-31   GFGC 1997-07-21     0.950
# 104 1998-04-16   10001   8.750000 1998-03-31   GFGC 1998-01-07     0.550
# 112 1998-12-17   10001   9.437500 1998-11-30   GFGC 1998-11-30     0.640
# 122 1999-10-14   10001   8.000000 1999-09-30   GFGC 1999-09-10     0.660
# 209 2003-07-17   10002  16.059999 2003-06-30   BTFG 2003-01-31     0.840
# 217 2004-03-18   10002  18.049999 2004-02-29   BTFG 2004-02-12     0.710
# 228 2005-02-17   10002  21.350000 2005-01-31   BTFG 2005-01-24     0.960
# 240 2006-02-16   10002  20.700001 2006-01-31   BTFG 2006-01-20     1.190
# 252 2007-02-15   10002  21.480000 2007-01-31   BTFG 2007-01-31     1.190
#
#      pred_date  pred_eps  mean_fpi2  year
# 23  1992-08-31     0.770       1.10  1991
# 36  1993-09-30     1.180       1.10  1992
# 46  1995-01-31     0.515       1.55  1993
# 57  1995-09-30     0.680       1.30  1994
# 72  1997-07-31     0.950       0.66  1995
# 83  1998-01-31     0.550       0.60  1996
# 96  1998-11-30     0.640       0.65  1997
# 104 1999-09-30     0.660       0.63  1998
# 112 2000-11-30     0.530       0.65  1998
# 122 2001-09-30     1.100       0.65  1999
# 209 2005-01-31     0.960       0.80  2003
# 217 2006-01-31     1.190       1.15  2004
# 228 2007-01-31     1.190       1.40  2005
# 240 2008-02-29     0.490       1.57  2006
# 252 2009-02-28     0.060       1.44  2007

# %%
X_tr2 = tr2[['prc', 'past_eps', 'mean_fpi2']]
y_tr2 = tr2['pred_eps']
X_ts2 = ts2[['prc', 'past_eps', 'mean_fpi2']]
y_ts2 = ts2['pred_eps']

# %%
X_tr2.shape
# Out:
# (69403, 3)

# %%
X_ts2.shape
# Out:
# (20514, 3)

# %%
for i in [3, 5, 7]:
    rf = RandomForestRegressor(random_state=0, n_estimators=100, max_depth=i, n_jobs=-1)
    rf.fit(X_tr2, y_tr2)
    yhat_tr2 = rf.predict(X_tr2)
    yhat_ts2 = rf.predict(X_ts2)
    inr2 = r2_score(y_tr2, yhat_tr2)
    outr2 = r2_score(y_ts2, yhat_ts2)
    print(datetime.now(), i, inr2, outr2)
# Out:
# 2020-11-16 11:26:09.814345 3 0.9733912509194751 0.7491527840365703
# 2020-11-16 11:26:10.704265 5 0.9759742447518011 0.7468097743456146
# 2020-11-16 11:26:11.690264 7 0.9755189425222143 0.7527612361355794

# %%
for i in [3, 5, 7]:
    rf = RandomForestRegressor(random_state=0, n_estimators=100, max_depth=i, n_jobs=-1)
    rf.fit(X_tr2, y_tr2)
    yhat_tr2 = rf.predict(X_tr2)
    yhat_ts2 = rf.predict(X_ts2)
    inr2 = r2_score(y_tr2, yhat_tr2)
    outr2 = r2_score(y_ts2, yhat_ts2)
    print(datetime.now(), i, inr2, outr2)
# Out:
# 2020-11-16 11:26:15.159983 3 0.9733912509194751 0.7491527840365703
# 2020-11-16 11:26:15.936782 5 0.9759742447518011 0.7468097743456146
# 2020-11-16 11:26:16.920342 7 0.9755189425222143 0.7527612361355794
